# %% [markdown]
# <a href="https://colab.research.google.com/github/hironorinaka99/DonkeyDocs/blob/master/paiza_B023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#s = input().strip()

s = "98765"

#Seg =["1111110","0110000","1101101","1111001","0110011","1011011","1011111","1110000","1111111","1111011"]

#print(s)
ans = []

check = 0

for x in range(len(s)): #同じ桁内での移動
    if s[x:x+1] == '0':
        ans.append(s[:x] + "6" + s[x+1:])
        ans.append(s[:x] + "9" + s[x+1:])
    elif s[x:x+1] == '2':
        ans.append(s[:x] + "3" + s[x+1:])
    elif s[x:x+1] == '3':
        ans.append(s[:x] + "2" + s[x+1:])
        ans.append(s[:x] + "5" + s[x+1:])
    elif s[x:x+1] == '5':
        ans.append(s[:x] + "3" + s[x+1:])
    elif s[x:x+1] == '6':
        ans.append(s[:x] + "0" + s[x+1:])
        ans.append(s[:x] + "9" + s[x+1:])
    elif s[x:x+1] == '9':
        ans.append(s[:x] + "0" + s[x+1:])
        ans.append(s[:x] + "6" + s[x+1:])
        
for x in range(len(s)): #減らす桁
    if s[x:x+1] == '6' or s[x:x+1] == '7' or s[x:x+1] == '8' or s[x:x+1] == '9': #減らす事が出来る数字がある場合
        for y in range(len(s)): #増やす桁

            if x == y: #同じ桁は処理しない
              continue
                
            if s[y:y+1] == '0' or s[y:y+1] == '1' or s[y:y+1] == '3' or s[y:y+1] == '5' or s[y:y+1] == '6' or s[y:y+1] == '9': #増やす事が出来る数字がある場合
                #print("replaceable!")
                if x > y: #増やす桁が左
                    if (s[y:y+1] == '0' or s[y:y+1] == '6' or s[y:y+1] == '9') and s[x:x+1] == '6':
                        ans.append(s[:y] + "8" +s[y+1:x] + "5" + s[x+1:])
                    elif (s[y:y+1] == '0' or s[y:y+1] == '6' or s[y:y+1] == '9') and s[x:x+1] == '7':
                        ans.append(s[:y] + "8" +s[y+1:x] + "1" + s[x+1:])
                    elif (s[y:y+1] == '0' or s[y:y+1] == '6' or s[y:y+1] == '9') and s[x:x+1] == '8':
                        ans.append(s[:y] + "8" +s[y+1:x] + "0" + s[x+1:])
                        ans.append(s[:y] + "8" +s[y+1:x] + "6" + s[x+1:])
                        ans.append(s[:y] + "8" +s[y+1:x] + "9" + s[x+1:])
                    elif (s[y:y+1] == '0' or s[y:y+1] == '6' or s[y:y+1] == '9') and s[x:x+1] == '9':
                        ans.append(s[:y] + "8" +s[y+1:x] + "5" + s[x+1:])
                        ans.append(s[:y] + "8" +s[y+1:x] + "3" + s[x+1:])

                    elif s[y:y+1] == '1' and s[x:x+1] == '6':
                        ans.append(s[:y] + "7" +s[y+1:x] + "5" + s[x+1:])
                    elif s[y:y+1] == '1' and s[x:x+1] == '7':
                        ans.append(s[:y] + "7" +s[y+1:x] + "1" + s[x+1:])
                    elif s[y:y+1] == '1' and s[x:x+1] == '8':
                        ans.append(s[:y] + "7" +s[y+1:x] + "0" + s[x+1:])
                        ans.append(s[:y] + "7" +s[y+1:x] + "6" + s[x+1:])
                        ans.append(s[:y] + "7" +s[y+1:x] + "9" + s[x+1:])
                    elif s[y:y+1] == '1' and s[x:x+1] == '9':
                        ans.append(s[:y] + "7" +s[y+1:x] + "5" + s[x+1:])
                        ans.append(s[:y] + "7" +s[y+1:x] + "3" + s[x+1:])

                    elif s[y:y+1] == '3' and s[x:x+1] == '6':
                        ans.append(s[:y] + "9" +s[y+1:x] + "5" + s[x+1:])
                    elif s[y:y+1] == '3' and s[x:x+1] == '7':
                        ans.append(s[:y] + "9" +s[y+1:x] + "1" + s[x+1:])
                    elif s[y:y+1] == '3' and s[x:x+1] == '8':
                        ans.append(s[:y] + "9" +s[y+1:x] + "0" + s[x+1:])
                        ans.append(s[:y] + "9" +s[y+1:x] + "6" + s[x+1:])
                        ans.append(s[:y] + "9" +s[y+1:x] + "9" + s[x+1:])
                    elif s[y:y+1] == '3' and s[x:x+1] == '9':
                        ans.append(s[:y] + "9" +s[y+1:x] + "5" + s[x+1:])
                        ans.append(s[:y] + "9" +s[y+1:x] + "3" + s[x+1:])

                    elif s[y:y+1] == '5' and s[x:x+1] == '6':
                        ans.append(s[:y] + "6" +s[y+1:x] + "5" + s[x+1:])
                        ans.append(s[:y] + "9" +s[y+1:x] + "5" + s[x+1:])
                    elif s[y:y+1] == '5' and s[x:x+1] == '7':
                        ans.append(s[:y] + "6" +s[y+1:x] + "1" + s[x+1:])
                        ans.append(s[:y] + "9" +s[y+1:x] + "1" + s[x+1:])
                    elif s[y:y+1] == '5' and s[x:x+1] == '8':
                        ans.append(s[:y] + "6" +s[y+1:x] + "0" + s[x+1:])
                        ans.append(s[:y] + "9" +s[y+1:x] + "6" + s[x+1:])
                        ans.append(s[:y] + "6" +s[y+1:x] + "9" + s[x+1:])
                        ans.append(s[:y] + "9" +s[y+1:x] + "0" + s[x+1:])
                        ans.append(s[:y] + "6" +s[y+1:x] + "6" + s[x+1:])
                        ans.append(s[:y] + "9" +s[y+1:x] + "9" + s[x+1:])
                    elif s[y:y+1] == '5' and s[x:x+1] == '9':
                        ans.append(s[:y] + "6" +s[y+1:x] + "5" + s[x+1:])
                        ans.append(s[:y] + "9" +s[y+1:x] + "5" + s[x+1:])
                        ans.append(s[:y] + "6" +s[y+1:x] + "3" + s[x+1:])
                        ans.append(s[:y] + "9" +s[y+1:x] + "3" + s[x+1:])

                else: #減らす桁が左
                    if  s[x:x+1] == '6' and (s[y:y+1] == '0' or s[y:y+1] == '6' or s[y:y+1] == '9'):
                        ans.append(s[:x] + "5" +s[x+1:y] + "8" + s[y+1:])
                    elif s[x:x+1] == '6' and s[y:y+1] == '1':
                        ans.append(s[:x] + "5" +s[x+1:y] + "7" + s[y+1:])
                    elif s[x:x+1] == '6' and s[y:y+1] == '3':
                        ans.append(s[:x] + "5" +s[x+1:y] + "9" + s[y+1:])
                    elif s[x:x+1] == '6' and s[y:y+1] == '5':
                        ans.append(s[:x] + "5" +s[x+1:y] + "6" + s[y+1:])
                        ans.append(s[:x] + "5" +s[x+1:y] + "9" + s[y+1:])
                    

                    if s[x:x+1] == '9' and (s[y:y+1] == '0' or s[y:y+1] == '6' or s[y:y+1] == '9'):
                        ans.append(s[:x] + "5" +s[x+1:y] + "8" + s[y+1:])
                        ans.append(s[:x] + "3" +s[x+1:y] + "8" + s[y+1:])
                    elif s[x:x+1] == '9' and s[y:y+1] == '1':
                        ans.append(s[:x] + "5" +s[x+1:y] + "7" + s[y+1:])
                        ans.append(s[:x] + "3" +s[x+1:y] + "7" + s[y+1:])
                    elif s[x:x+1] == '9' and s[y:y+1] == '3':
                        ans.append(s[:x] + "5" +s[x+1:y] + "9" + s[y+1:])
                        ans.append(s[:x] + "3" +s[x+1:y] + "9" + s[y+1:])
                    elif s[x:x+1] == '9' and s[y:y+1] == '5':
                        ans.append(s[:x] + "5" +s[x+1:y] + "6" + s[y+1:])
                        ans.append(s[:x] + "5" +s[x+1:y] + "9" + s[y+1:])
                        ans.append(s[:x] + "3" +s[x+1:y] + "6" + s[y+1:])
                        ans.append(s[:x] + "3" +s[x+1:y] + "9" + s[y+1:])
                    
                    elif s[x:x+1] == '7' and (s[y:y+1] == '0' or s[y:y+1] == '6' or s[y:y+1] == '9'):
                        ans.append(s[:x] + "1" +s[x+1:y] + "8" + s[y+1:])
                    elif s[x:x+1] == '7' and s[y:y+1] == '1':
                        ans.append(s[:x] + "1" +s[x+1:y] + "7" + s[y+1:])
                    elif s[x:x+1] == '7' and s[y:y+1] == '3':
                        ans.append(s[:x] + "1" +s[x+1:y] + "9" + s[y+1:])
                    elif s[x:x+1] == '7' and s[y:y+1] == '5':
                        ans.append(s[:x] + "1" +s[x+1:y] + "6" + s[y+1:])
                        ans.append(s[:x] + "1" +s[x+1:y] + "9" + s[y+1:])

                    elif s[x:x+1] == '8' and (s[y:y+1] == '0' or s[y:y+1] == '6' or s[y:y+1] == '9'):
                        ans.append(s[:x] + "0" +s[x+1:y] + "8" + s[y+1:])
                        ans.append(s[:x] + "6" +s[x+1:y] + "8" + s[y+1:])
                        ans.append(s[:x] + "9" +s[x+1:y] + "8" + s[y+1:])
                    elif s[x:x+1] == '8' and s[y:y+1] == '1':
                        ans.append(s[:x] + "0" +s[x+1:y] + "7" + s[y+1:])
                        ans.append(s[:x] + "6" +s[x+1:y] + "7" + s[y+1:])
                        ans.append(s[:x] + "9" +s[x+1:y] + "7" + s[y+1:])
                    elif s[x:x+1] == '8' and s[y:y+1] == '3':
                        ans.append(s[:x] + "0" +s[x+1:y] + "9" + s[y+1:])
                        ans.append(s[:x] + "6" +s[x+1:y] + "9" + s[y+1:])
                        ans.append(s[:x] + "9" +s[x+1:y] + "9" + s[y+1:])
                    elif s[x:x+1] == '8' and s[y:y+1] == '5':
                        ans.append(s[:x] + "0" +s[x+1:y] + "6" + s[y+1:])
                        ans.append(s[:x] + "6" +s[x+1:y] + "6" + s[y+1:])
                        ans.append(s[:x] + "9" +s[x+1:y] + "6" + s[y+1:])
                        ans.append(s[:x] + "0" +s[x+1:y] + "9" + s[y+1:])
                        ans.append(s[:x] + "6" +s[x+1:y] + "9" + s[y+1:])
                        ans.append(s[:x] + "9" +s[x+1:y] + "9" + s[y+1:])

list(set(ans))

#print("before sort")
#print(ans)

ans.sort()
#print("sorted")
#print(ans)

if len(ans) == 0:
    print("none")
else:
    for x in range(len(ans)):
        print(ans[x])
# Out:
# 08765
# 38766
# 38769
# 38785
# 58766
# 58769
# 58785
# 68765
# 80765
# 86765
# 88165
# 88755
# 89765
# 90766
# 90769
# 90785
# 96766
# 96769
# 96785
# 98166
# 98169
# 98185
# 98705
# 98756
# 98759
# 98763
# 98795
# 99766
# 99769
# 99785
